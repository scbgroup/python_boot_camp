# %% [markdown]
# # Python Boot Camp
# ## CHEMS
# ## Wednesday, June 19, 2024

# %% [markdown]
# # Preface
#
#  - This workshop is based on "Python Boot Camp", a D2L module prepared for students in CHE 431 "Chemical Reactor Engineering", starting in Fall 2020.
#  - The module is intended to be self-paced, but we will go through it together.
#      - might be simultaneously too fast and too slow!
#  - Based on MATLAB Onramp, a similar self-paced tutorial.
#  - Some background in MATLAB is probably assumed.
#  - I would deeply appreciate any feedback, positive or negative!

# %% [markdown]
# # Updates
#
# This content is a little out of date for two reasons:
#
#  - [**Jupyter Notebook**](https://jupyter.org) has been updated to [**Jupyter Lab**](https://jupyter.org)
#  - `%pylab inline` has been deprecated so we'll use `from pylab import *`
#
# The plan is/was to update this summer!

# %% [markdown]
# ![Screenshot 2024-06-19 at 6.09.15 AM.jpg](attachment:f133926b-44e8-4ef6-8a83-cbdc708478ac.jpg)

# %% [markdown]
# # Outline
#
#  - **Getting Started with Jupyter** - usage and features of Jupyter
#  - **Python Basics** - learning python using Jupyter Notebooks
#      1. Commands
#      2. Python Functions and Packages
#      3. 1D and 2D Arrays
#      4. Loading and Saving Data
#      5. Indexing into and Modifying Arrays
#      6. Array Calculations
#      7. Calling Functions
#      8. Plotting Data
#      9. Obtaining Help
#
# - **Challenge Problem 1**: Diffusion in Catalyst Pellets
# - **Next Meeting**
